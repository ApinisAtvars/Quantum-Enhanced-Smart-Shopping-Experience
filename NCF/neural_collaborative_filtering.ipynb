# %% [markdown]
# # PyTorch Implementation of Neural Collaborative Filtering
# >Paper [here](https://arxiv.org/pdf/1708.05031)
#
# >Authors' implementation in Tensorflow [here](https://github.com/hexiangnan/neural_collaborative_filtering)

# %% [markdown]
# ## Generalized Matrix Factorization Module

# %%
import torch
from torch import nn
